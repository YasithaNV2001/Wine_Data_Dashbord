# %%
import pandas as pd
import os

# %%
# Load CSV files into a list
csv_files = ["D:\project NV\python_bootcamp\Bootcamp\CASE1\CASE1\Wine_Stats/Australia_Wine_Stats.csv",
             "D:\project NV\python_bootcamp\Bootcamp\CASE1\CASE1\Wine_Stats/Chile_Wine_Stats.csv",
             "D:\project NV\python_bootcamp\Bootcamp\CASE1\CASE1\Wine_Stats/France_Wine_Stats.csv",
             "D:\project NV\python_bootcamp\Bootcamp\CASE1\CASE1\Wine_Stats/Italy_Wine_Stats.csv", 
             "D:\project NV\python_bootcamp\Bootcamp\CASE1\CASE1\Wine_Stats/New Zealand_Wine_Stats.csv",
            "D:\project NV\python_bootcamp\Bootcamp\CASE1\CASE1\Wine_Stats/Portugal_Wine_Stats.csv",
            "D:\project NV\python_bootcamp\Bootcamp\CASE1\CASE1\Wine_Stats/Spain_Wine_Stats.csv ",
            "D:\project NV\python_bootcamp\Bootcamp\CASE1\CASE1\Wine_Stats/USA_Wine_Stats.csv"]  # Replace with actual file names/paths


data_frames = [pd.read_csv(file) for file in csv_files]

# Concatenate into a single DataFrame
wine_df = pd.concat(data_frames, ignore_index=True)

# Display the first few rows
wine_df.head()
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\p'
# <>:3: SyntaxWarning: invalid escape sequence '\p'
# <>:4: SyntaxWarning: invalid escape sequence '\p'
# <>:5: SyntaxWarning: invalid escape sequence '\p'
# <>:6: SyntaxWarning: invalid escape sequence '\p'
# <>:7: SyntaxWarning: invalid escape sequence '\p'
# <>:8: SyntaxWarning: invalid escape sequence '\p'
# <>:9: SyntaxWarning: invalid escape sequence '\p'
# <>:2: SyntaxWarning: invalid escape sequence '\p'
# <>:3: SyntaxWarning: invalid escape sequence '\p'
# <>:4: SyntaxWarning: invalid escape sequence '\p'
# <>:5: SyntaxWarning: invalid escape sequence '\p'
# <>:6: SyntaxWarning: invalid escape sequence '\p'
# <>:7: SyntaxWarning: invalid escape sequence '\p'
# <>:8: SyntaxWarning: invalid escape sequence '\p'
# <>:9: SyntaxWarning: invalid escape sequence '\p'
# C:\Users\User\AppData\Local\Temp\ipykernel_9064\3290463018.py:2: SyntaxWarning: invalid escape sequence '\p'
# ...
